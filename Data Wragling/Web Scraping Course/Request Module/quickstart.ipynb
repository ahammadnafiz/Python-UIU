# %% [markdown]
# ### Make a Request

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')
print(r.json())
# Out:
# [{'id': '48206236671', 'type': 'PushEvent', 'actor': {'id': 116446131, 'login': 'Twiist33', 'display_login': 'Twiist33', 'gravatar_id': '', 'url': 'https://api.github.com/users/Twiist33', 'avatar_url': 'https://avatars.githubusercontent.com/u/116446131?'}, 'repo': {'id': 958740514, 'name': 'Twiist33/Others_projects', 'url': 'https://api.github.com/repos/Twiist33/Others_projects'}, 'payload': {'repository_id': 958740514, 'push_id': 23506837130, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': 'b7d1a043bd3775a639395412e7f01bd8efe76279', 'before': '52fd6b80c0e97e22bbd839d4586cbc95973e3d62', 'commits': [{'sha': 'b7d1a043bd3775a639395412e7f01bd8efe76279', 'author': {'email': '116446131+Twiist33@users.noreply.github.com', 'name': 'Romain_Traboul'}, 'message': 'Create README.md', 'distinct': True, 'url': 'https://api.github.com/repos/Twiist33/Others_projects/commits/b7d1a043bd3775a639395412e7f01bd8efe76279'}]}, 'public': True, 'created_at': '2025-04-01T17:40:48Z'}, {'id': '4
# ...

# %% [markdown]
# ### Passing Parameters In URLs

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get('https://httpbin.org/get', params=payload)
print(r.url)
# Out:
# https://httpbin.org/get?key1=value1&key2=value2

# %% [markdown]
# ### Understand Get Method in Request

# %%
uri = 'https://api.github.com'
response = requests.get(uri)
print(response.status_code)
# Out:
# 200

# %%
response.content[:1000]
# Out:
# b'{"current_user_url":"https://api.github.com/user","current_user_authorizations_html_url":"https://github.com/settings/connections/applications{/client_id}","authorizations_url":"https://api.github.com/authorizations","code_search_url":"https://api.github.com/search/code?q={query}{&page,per_page,sort,order}","commit_search_url":"https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}","emails_url":"https://api.github.com/user/emails","emojis_url":"https://api.github.com/emojis","events_url":"https://api.github.com/events","feeds_url":"https://api.github.com/feeds","followers_url":"https://api.github.com/user/followers","following_url":"https://api.github.com/user/following{/target}","gists_url":"https://api.github.com/gists{/gist_id}","hub_url":"https://api.github.com/hub","issue_search_url":"https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}","issues_url":"https://api.github.com/issues","keys_url":"https://api.github.com/user/keys","label_s
# ...

# %% [markdown]
# ### Query Parameters

# %%
uri = 'https://api.github.com/search/repositories'
params = {'q': 'requests+language:python'}
response = requests.get(uri, params=params)

# %%
response.content[:1000]
# Out:
# b'{"total_count":250,"incomplete_results":false,"items":[{"id":33210074,"node_id":"MDEwOlJlcG9zaXRvcnkzMzIxMDA3NA==","name":"secrules-language-evaluation","full_name":"SpiderLabs/secrules-language-evaluation","private":false,"owner":{"login":"SpiderLabs","id":508521,"node_id":"MDEyOk9yZ2FuaXphdGlvbjUwODUyMQ==","avatar_url":"https://avatars.githubusercontent.com/u/508521?v=4","gravatar_id":"","url":"https://api.github.com/users/SpiderLabs","html_url":"https://github.com/SpiderLabs","followers_url":"https://api.github.com/users/SpiderLabs/followers","following_url":"https://api.github.com/users/SpiderLabs/following{/other_user}","gists_url":"https://api.github.com/users/SpiderLabs/gists{/gist_id}","starred_url":"https://api.github.com/users/SpiderLabs/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/SpiderLabs/subscriptions","organizations_url":"https://api.github.com/users/SpiderLabs/orgs","repos_url":"https://api.github.com/users/SpiderLabs/repos","events_url
# ...

# %%
response.url
# Out:
# 'https://api.github.com/search/repositories?q=requests%2Blanguage%3Apython'

# %%
response = requests.get('https://www.wikipedia.org')

# %%
print(f"Status Code: {response.status_code}")
# Out:
# Status Code: 200

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html lang="en" class="no-js">\n<head>\n<meta charset="utf-8">\n<title>Wikipedia</title>\n<meta name="description" content="Wikipedia is a free online encyclopedia, created and edited by volunteers around the world and hosted by the Wikimedia Foundation.">\n<script>\ndocument.documentElement.className = document.documentElement.className.replace( /(^|\\s)no-js(\\s|$)/, "$1js-enabled$2" );\n</script>\n<meta name="viewport" content="initial-scale=1,user-scalable=yes">\n<link rel="apple-touch-icon" href="/static/apple-touch/wikipedia.png">\n<link rel="shortcut icon" href="/static/favicon/wikipedia.ico">\n<link rel="license" href="//creativecommons.org/licenses/by-sa/4.0/">\n<style>\n.sprite{background-image:linear-gradient(transparent,transparent),url(portal/wikipedia.org/assets/img/sprite-de847d1a.svg);background-repeat:no-repeat;display:inline-block;vertical-align:middle}.svg-Commons-logo_sister{background-position:0 0;width:47px;height:47px}.svg-MediaWiki-logo_siste
# ...

# %%
print(response.text.split('</title>')[0].split('<title>')[1])
# Out:
# Wikipedia

# %%
api_key = "2203972e70f562c3bea789d695129ca6"
city = "Bhola"
params = {
    'q': city,
    'appid': api_key,
    'units': 'metric'
}
response = requests.get('https://api.openweathermap.org/data/2.5/weather', params=params)
if response.status_code == 200:
    weather_data = response.json()
    print(f"Temperature in {city}: {weather_data['main']['temp']}°C")
    print(f"Weather: {weather_data['weather'][0]['description']}")
# Out:
# Temperature in Bhola: 25.7°C
# Weather: scattered clouds

# %%
response.url
# Out:
# 'https://api.openweathermap.org/data/2.5/weather?q=Bhola&appid=2203972e70f562c3bea789d695129ca6&units=metric'

# %%
response = requests.get('https://jsonplaceholder.typicode.com/posts/1')
if response.status_code == 200:
    post = response.json()
    print(f"Post Title: {post['title']}")
    print(f"Post Body: {post['body']}")
# Out:
# Post Title: sunt aut facere repellat provident occaecati excepturi optio reprehenderit
# Post Body: quia et suscipit
# suscipit recusandae consequuntur expedita et cum
# reprehenderit molestiae ut ut quas totam
# nostrum rerum est autem sunt rem eveniet architecto

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get('https://news.ycombinator.com/')
soup = BeautifulSoup(response.content, 'html.parser')
stories = soup.find_all('span', class_='titleline')

print("Top Hacker News stories:")
for i, story in enumerate(stories[:5], 1):
    title = story.find('a').text
    link = story.find('a')['href']
    print(f"{i}. {title}")
    print(f"   Link: {link}")
# Out:
# Top Hacker News stories:
# 1. Electron band structure in germanium, my ass
#    Link: https://pages.cs.wisc.edu/~kovar/hall.html
# 2. Bletchley code breaker Betty Webb dies aged 101
#    Link: https://www.bbc.com/news/articles/c78jd30ywv8o
# 3. A man powers home for eight years using a thousand old laptop batteries
#    Link: https://techoreon.com/a-man-powers-home-8-years-laptop-batteries/
# 4. The Myst Graph: A New Perspective on Myst
#    Link: https://glthr.com/myst-graph-1
# 5. Systems Correctness Practices at AWS: Leveraging Formal and Semi-Formal Methods
#    Link: https://queue.acm.org/detail.cfm?id=3712057

# %% [markdown]
# ### Post Method

# %%
uri = 'https://httpbin.org/post'
data = {
    'username': 'john_doe',
    'password': 's3cr3t'
}

# %%
response = requests.post(uri, data=data)

# %%
response.json()
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'password': 's3cr3t', 'username': 'john_doe'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate, br, zstd',
#   'Content-Length': '33',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.32.3',
#   'X-Amzn-Trace-Id': 'Root=1-67ec277e-014f3ccf410c8b37103fe603'},
#  'json': None,
#  'origin': '118.179.116.241',
#  'url': 'https://httpbin.org/post'}

# %%
response.json()['headers']['Content-Type'].split('/')[-1]
# Out:
# 'x-www-form-urlencoded'

# %%
response = requests.post(uri, json=data)

# %%
response.json()
# Out:
# {'args': {},
#  'data': '{"username": "john_doe", "password": "s3cr3t"}',
#  'files': {},
#  'form': {},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate, br, zstd',
#   'Content-Length': '46',
#   'Content-Type': 'application/json',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.32.3',
#   'X-Amzn-Trace-Id': 'Root=1-67ec278d-18d81a380d50cfd81660e0e4'},
#  'json': {'password': 's3cr3t', 'username': 'john_doe'},
#  'origin': '118.179.116.241',
#  'url': 'https://httpbin.org/post'}

# %% [markdown]
# ### Sending JSON data to JSONPlaceholder

# %%
import json

# Data to send as JSON
post_data = {
    'title': 'My New Post',
    'body': 'This is the content of my post',
    'userId': 1
}

# Send POST request with JSON data
headers = {'Content-Type': 'application/json'}
response = requests.post(
    'https://jsonplaceholder.typicode.com/posts',
    data=json.dumps(post_data),
    headers=headers
)

# Alternative way to send JSON data
# response = requests.post(
#     'https://jsonplaceholder.typicode.com/posts',
#     json=post_data  # requests automatically handles JSON serialization
# )

print(f"Status code: {response.status_code}")
print(f"Response: {response.json()}")
# Out:
# Status code: 201
# Response: {'title': 'My New Post', 'body': 'This is the content of my post', 'userId': 1, 'id': 101}

# %% [markdown]
# ### Form submission

# %%
# Contact form submission example
form_data = {
    'name': 'John Doe',
    'email': 'john@example.com',
    'message': 'Hello, this is a test message!'
}

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
}

response = requests.post('https://httpbin.org/post', data=form_data, headers=headers)
print(f"Status code: {response.status_code}")
print(response.json())
# Out:
# Status code: 200
# {'args': {}, 'data': '', 'files': {}, 'form': {'email': 'john@example.com', 'message': 'Hello, this is a test message!', 'name': 'John Doe'}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Content-Length': '81', 'Content-Type': 'application/x-www-form-urlencoded', 'Host': 'httpbin.org', 'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36', 'X-Amzn-Trace-Id': 'Root=1-67ec27bb-12cbecc22be151cc0f9f1300'}, 'json': None, 'origin': '118.179.116.241', 'url': 'https://httpbin.org/post'}

# %%
response.json()['headers']['Content-Type'].split('/')[-1]
# Out:
# 'x-www-form-urlencoded'

# %% [markdown]
# ### File upload to a server

# %%
# File upload example
files = {
    'file': ('report.csv', open('report.csv', 'rb'), 'text/csv')
}

response = requests.post('https://httpbin.org/post', files=files)
print(f"Status code: {response.status_code}")
print(response.json())
# Out:
# Status code: 200
# {'args': {}, 'data': '', 'files': {'file': 'name,age\nAlice,30\nBob,25\nCharlie,40'}, 'form': {}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Content-Length': '205', 'Content-Type': 'multipart/form-data; boundary=229ea1f7c24197eeafb15935d81d53af', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.32.3', 'X-Amzn-Trace-Id': 'Root=1-67ec27cd-2f52d3300bf219a875b783da'}, 'json': None, 'origin': '118.179.116.241', 'url': 'https://httpbin.org/post'}

# %%
response.json()['files']['file']
# Out:
# 'name,age\nAlice,30\nBob,25\nCharlie,40'

# %% [markdown]
# ### Put Method

# %%
uri = 'https://httpbin.org/put'
data = {
    'username': 'john_doe',
    'password': 's3cr3t'
}

# %%
response = requests.put(uri, data=data)

# %%
response.json()
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'password': 's3cr3t', 'username': 'john_doe'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate, br, zstd',
#   'Content-Length': '33',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.32.3',
#   'X-Amzn-Trace-Id': 'Root=1-67ec27d5-22d41b23615e49be1540a9fb'},
#  'json': None,
#  'origin': '118.179.116.241',
#  'url': 'https://httpbin.org/put'}

# %% [markdown]
# ### Delete Method

# %%
uri = 'https://httpbin.org/delete'

# %%
response = requests.delete(uri)

# %%
response.json()
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate, br, zstd',
#   'Content-Length': '0',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.32.3',
#   'X-Amzn-Trace-Id': 'Root=1-67ec27dd-581785515b5901d908e79e10'},
#  'json': None,
#  'origin': '118.179.116.241',
#  'url': 'https://httpbin.org/delete'}

# %% [markdown]
# ### Headers

# %%
uri = 'https://httpbin.org/headers'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept': 'application/json',
    'Content-Type': 'application/json',
    'X-Custom-Header': 'value',
    'Authorization': 'YourTokenHere'
}

# %%
response = requests.get(uri, headers=headers)

# %%
response.json()
# Out:
# {'headers': {'Accept': 'application/json',
#   'Accept-Encoding': 'gzip, deflate, br, zstd',
#   'Accept-Language': 'en-US,en;q=0.5',
#   'Authorization': 'YourTokenHere',
#   'Content-Type': 'application/json',
#   'Host': 'httpbin.org',
#   'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36',
#   'X-Amzn-Trace-Id': 'Root=1-67ec27f3-6a6c209767d8af3b628a7f1f',
#   'X-Custom-Header': 'value'}}

# %%
response.headers
# Out:
# {'Date': 'Tue, 01 Apr 2025 17:52:51 GMT', 'Content-Type': 'application/json', 'Content-Length': '441', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}

# %%
type(response.headers)
# Out:
# requests.structures.CaseInsensitiveDict

# %%
dict(response.headers)
# Out:
# {'Date': 'Tue, 01 Apr 2025 17:52:51 GMT',
#  'Content-Type': 'application/json',
#  'Content-Length': '441',
#  'Connection': 'keep-alive',
#  'Server': 'gunicorn/19.9.0',
#  'Access-Control-Allow-Origin': '*',
#  'Access-Control-Allow-Credentials': 'true'}

# %%
response.json()['headers']
# Out:
# {'Accept': 'application/json',
#  'Accept-Encoding': 'gzip, deflate, br, zstd',
#  'Accept-Language': 'en-US,en;q=0.5',
#  'Authorization': 'YourTokenHere',
#  'Content-Type': 'application/json',
#  'Host': 'httpbin.org',
#  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36',
#  'X-Amzn-Trace-Id': 'Root=1-67ec27f3-6a6c209767d8af3b628a7f1f',
#  'X-Custom-Header': 'value'}

# %%
for key, value in response.json()['headers'].items():
    print(f"{key:<16}: {value}")
# Out:
# Accept          : application/json
# Accept-Encoding : gzip, deflate, br, zstd
# Accept-Language : en-US,en;q=0.5
# Authorization   : YourTokenHere
# Content-Type    : application/json
# Host            : httpbin.org
# User-Agent      : Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36
# X-Amzn-Trace-Id : Root=1-67ec27f3-6a6c209767d8af3b628a7f1f
# X-Custom-Header : value

# %% [markdown]
# ### Response Object

# %%
uri = 'https://api.github.com'

# %%
response = requests.get(uri)

# %%
response.status_code
# Out:
# 200

# %%
response.headers
# Out:
# {'Date': 'Tue, 01 Apr 2025 17:53:21 GMT', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept,Accept-Encoding, Accept, X-Requested-With', 'ETag': '"4f825cc84e1c733059d46e76e6df9db557ae5254f9625dfe8e1b09499c449438"', 'x-github-api-version-selected': '2022-11-28', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Server': 'github.com', 'Content-Type': 'application/json; charset=u
# ...

# %%
response.content[:1000]
# Out:
# b'{\n  "current_user_url": "https://api.github.com/user",\n  "current_user_authorizations_html_url": "https://github.com/settings/connections/applications{/client_id}",\n  "authorizations_url": "https://api.github.com/authorizations",\n  "code_search_url": "https://api.github.com/search/code?q={query}{&page,per_page,sort,order}",\n  "commit_search_url": "https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}",\n  "emails_url": "https://api.github.com/user/emails",\n  "emojis_url": "https://api.github.com/emojis",\n  "events_url": "https://api.github.com/events",\n  "feeds_url": "https://api.github.com/feeds",\n  "followers_url": "https://api.github.com/user/followers",\n  "following_url": "https://api.github.com/user/following{/target}",\n  "gists_url": "https://api.github.com/gists{/gist_id}",\n  "hub_url": "https://api.github.com/hub",\n  "issue_search_url": "https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}",\n  "issues_url": "https://ap
# ...

# %%
response.text
# Out:
# '{\n  "current_user_url": "https://api.github.com/user",\n  "current_user_authorizations_html_url": "https://github.com/settings/connections/applications{/client_id}",\n  "authorizations_url": "https://api.github.com/authorizations",\n  "code_search_url": "https://api.github.com/search/code?q={query}{&page,per_page,sort,order}",\n  "commit_search_url": "https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}",\n  "emails_url": "https://api.github.com/user/emails",\n  "emojis_url": "https://api.github.com/emojis",\n  "events_url": "https://api.github.com/events",\n  "feeds_url": "https://api.github.com/feeds",\n  "followers_url": "https://api.github.com/user/followers",\n  "following_url": "https://api.github.com/user/following{/target}",\n  "gists_url": "https://api.github.com/gists{/gist_id}",\n  "hub_url": "https://api.github.com/hub",\n  "issue_search_url": "https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}",\n  "issues_url": "https://api
# ...

# %%
type(response.text)
# Out:
# str

# %%
response.content
# Out:
# b'{\n  "current_user_url": "https://api.github.com/user",\n  "current_user_authorizations_html_url": "https://github.com/settings/connections/applications{/client_id}",\n  "authorizations_url": "https://api.github.com/authorizations",\n  "code_search_url": "https://api.github.com/search/code?q={query}{&page,per_page,sort,order}",\n  "commit_search_url": "https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}",\n  "emails_url": "https://api.github.com/user/emails",\n  "emojis_url": "https://api.github.com/emojis",\n  "events_url": "https://api.github.com/events",\n  "feeds_url": "https://api.github.com/feeds",\n  "followers_url": "https://api.github.com/user/followers",\n  "following_url": "https://api.github.com/user/following{/target}",\n  "gists_url": "https://api.github.com/gists{/gist_id}",\n  "hub_url": "https://api.github.com/hub",\n  "issue_search_url": "https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}",\n  "issues_url": "https://ap
# ...

# %%
type(response.content)
# Out:
# bytes

# %%
dict(response.headers)
# Out:
# {'Date': 'Tue, 01 Apr 2025 17:53:21 GMT',
#  'Cache-Control': 'public, max-age=60, s-maxage=60',
#  'Vary': 'Accept,Accept-Encoding, Accept, X-Requested-With',
#  'ETag': '"4f825cc84e1c733059d46e76e6df9db557ae5254f9625dfe8e1b09499c449438"',
#  'x-github-api-version-selected': '2022-11-28',
#  'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset',
#  'Access-Control-Allow-Origin': '*',
#  'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload',
#  'X-Frame-Options': 'deny',
#  'X-Content-Type-Options': 'nosniff',
#  'X-XSS-Protection': '0',
#  'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin',
#  'Content-Security-Policy': "default-src 'none'",
#  'Server': 'github.com',
# ...

# %%
for key, value in dict(response.json()).items():
    print(f"{key:<30}: {value}")
# Out:
# current_user_url              : https://api.github.com/user
# current_user_authorizations_html_url: https://github.com/settings/connections/applications{/client_id}
# authorizations_url            : https://api.github.com/authorizations
# code_search_url               : https://api.github.com/search/code?q={query}{&page,per_page,sort,order}
# commit_search_url             : https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}
# emails_url                    : https://api.github.com/user/emails
# emojis_url                    : https://api.github.com/emojis
# events_url                    : https://api.github.com/events
# feeds_url                     : https://api.github.com/feeds
# followers_url                 : https://api.github.com/user/followers
# following_url                 : https://api.github.com/user/following{/target}
# gists_url                     : https://api.github.com/gists{/gist_id}
# ...
