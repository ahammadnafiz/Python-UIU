# %% [markdown]
# ### Make a Request

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')
print(r.json())
# Out:
# [{'id': '47685868888', 'type': 'PullRequestEvent', 'actor': {'id': 58892664, 'login': 'rcontreras1337', 'display_login': 'rcontreras1337', 'gravatar_id': '', 'url': 'https://api.github.com/users/rcontreras1337', 'avatar_url': 'https://avatars.githubusercontent.com/u/58892664?'}, 'repo': {'id': 939025008, 'name': 'LIDR-academy/AI4Devs-design-1', 'url': 'https://api.github.com/repos/LIDR-academy/AI4Devs-design-1'}, 'payload': {'action': 'opened', 'number': 45, 'pull_request': {'url': 'https://api.github.com/repos/LIDR-academy/AI4Devs-design-1/pulls/45', 'id': 2400897549, 'node_id': 'PR_kwDON_hicM6PGsoN', 'html_url': 'https://github.com/LIDR-academy/AI4Devs-design-1/pull/45', 'diff_url': 'https://github.com/LIDR-academy/AI4Devs-design-1/pull/45.diff', 'patch_url': 'https://github.com/LIDR-academy/AI4Devs-design-1/pull/45.patch', 'issue_url': 'https://api.github.com/repos/LIDR-academy/AI4Devs-design-1/issues/45', 'number': 45, 'state': 'open', 'locked': False, 'title': 'Diseño LIT', 'user': {'login': 'rcontreras1337', 'id': 58892664, 'node_id': 'MDQ6VXNlcjU4ODkyNjY0', 'avatar_url': 'https://avatars.githubusercontent.com/u/58892664?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/rcontreras1337', 'html_url': 'https://github.com/rcontreras1337', 'followers_url': 'https://api.github.com/users/rcontreras1337/followers', 'following_url': 'https://api.github.com/users/rcontreras1337/following{/other_user}', 'gists_url': 'https://api.github.com/users/rcontreras1337/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/rcontreras1337/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/rcontreras1337/subscriptions', 'organizations_url': 'https://api.github.com/users/rcontreras1337/orgs', 'repos_url': 'https://api.github.com/users/rcontreras1337/repos', 'events_url': 'https://api.github.com/users/rcontreras1337/events{/privacy}', 'received_events_url': 'https://api.github.com/users/rcontreras1337/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'body': None, 'created_at': '2025-03-18T13:21:50Z', 'updated_at': '2025-03-18T13:21:50Z', 'closed_at': None, 'merged_at': None, 'merge_commit_sha': None, 'assignee': None, 'assignees': [], 'requested_reviewers': [], 'requested_teams': [], 'labels': [], 'milestone': None, 'draft': False, 'commits_url': 'https://api.github.com/repos/LIDR-academy/AI4Devs-design-1/pulls/45/commits', 'review_comments_url': 'https://api.github.com/repos/LIDR-academy/AI4Devs-design-1/pulls/45/comments', 'review_comment_url': 'https://api.github.com/repos/LIDR-academy/AI4Devs-design-1/pulls/comments{/number}', 'comments_url': 'https://api.github.com/repos/LIDR-academy/AI4Devs-design-1/issues/45/comments', 'statuses_url': 'https://api.github.com/repos/LIDR-academy/AI4Devs-design-1/statuses/745e8698acbd7a471467ee884eefdf41019874d3', 'head': {'label': 'rcontreras1337:LIT-RCB', 'ref': 'LIT-RCB', 'sha': '745e8698acbd7a471467ee884eefdf41019874d3', 'user': {'login': 'rcontreras1337', 'id': 58892664, 'node_id': 'MDQ6VXNlcjU4ODkyNjY0', 'avatar_url': 'https://avatars.githubusercontent.com/u/58892664?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/rcontreras1337', 'html_url': 'https://github.com/rcontreras1337', 'followers_url': 'https://api.github.com/users/rcontreras1337/followers', 'following_url': 'https://api.github.com/users/rcontreras1337/following{/other_user}', 'gists_url': 'https://api.github.com/users/rcontreras1337/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/rcontreras1337/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/rcontreras1337/subscriptions', 'organizations_url': 'https://api.github.com/users/rcontreras1337/orgs', 'repos_url': 'https://api.github.com/users/rcontreras1337/repos', 'events_url': 'https://api.github.com/users/rcontreras1337/events{/privacy}', 'received_events_url': 'https://api.github.com/users/rcontreras1337/received_events', 'type': 'User', 'user_view_type': 'pu ...

# %% [markdown]
# ### Passing Parameters In URLs

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get('https://httpbin.org/get', params=payload)
print(r.url)
# Out:
# https://httpbin.org/get?key1=value1&key2=value2

# %% [markdown]
# ### Understand Get Method in Request

# %%
uri = 'https://api.github.com'
response = requests.get(uri)
print(response.status_code)
# Out:
# 200

# %%
response.content[:1000]
# Out:
# b'{\n  "current_user_url": "https://api.github.com/user",\n  "current_user_authorizations_html_url": "https://github.com/settings/connections/applications{/client_id}",\n  "authorizations_url": "https://api.github.com/authorizations",\n  "code_search_url": "https://api.github.com/search/code?q={query}{&page,per_page,sort,order}",\n  "commit_search_url": "https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}",\n  "emails_url": "https://api.github.com/user/emails",\n  "emojis_url": "https://api.github.com/emojis",\n  "events_url": "https://api.github.com/events",\n  "feeds_url": "https://api.github.com/feeds",\n  "followers_url": "https://api.github.com/user/followers",\n  "following_url": "https://api.github.com/user/following{/target}",\n  "gists_url": "https://api.github.com/gists{/gist_id}",\n  "hub_url": "https://api.github.com/hub",\n  "issue_search_url": "https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}",\n  "issues_url": "https://api.github.com/issues'

# %% [markdown]
# ### Query Parameters

# %%
uri = 'https://api.github.com/search/repositories'
params = {'q': 'requests+language:python'}
response = requests.get(uri, params=params)

# %%
response.content[:1000]
# Out:
# b'{"total_count":248,"incomplete_results":false,"items":[{"id":33210074,"node_id":"MDEwOlJlcG9zaXRvcnkzMzIxMDA3NA==","name":"secrules-language-evaluation","full_name":"SpiderLabs/secrules-language-evaluation","private":false,"owner":{"login":"SpiderLabs","id":508521,"node_id":"MDEyOk9yZ2FuaXphdGlvbjUwODUyMQ==","avatar_url":"https://avatars.githubusercontent.com/u/508521?v=4","gravatar_id":"","url":"https://api.github.com/users/SpiderLabs","html_url":"https://github.com/SpiderLabs","followers_url":"https://api.github.com/users/SpiderLabs/followers","following_url":"https://api.github.com/users/SpiderLabs/following{/other_user}","gists_url":"https://api.github.com/users/SpiderLabs/gists{/gist_id}","starred_url":"https://api.github.com/users/SpiderLabs/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/SpiderLabs/subscriptions","organizations_url":"https://api.github.com/users/SpiderLabs/orgs","repos_url":"https://api.github.com/users/SpiderLabs/repos","events_url":"h'

# %%
response.url
# Out:
# 'https://api.github.com/search/repositories?q=requests%2Blanguage%3Apython'

# %%
response = requests.get('https://www.wikipedia.org')

# %%
print(f"Status Code: {response.status_code}")
# Out:
# Status Code: 200

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html lang="en" class="no-js">\n<head>\n<meta charset="utf-8">\n<title>Wikipedia</title>\n<meta name="description" content="Wikipedia is a free online encyclopedia, created and edited by volunteers around the world and hosted by the Wikimedia Foundation.">\n<script>\ndocument.documentElement.className = document.documentElement.className.replace( /(^|\\s)no-js(\\s|$)/, "$1js-enabled$2" );\n</script>\n<meta name="viewport" content="initial-scale=1,user-scalable=yes">\n<link rel="apple-touch-icon" href="/static/apple-touch/wikipedia.png">\n<link rel="shortcut icon" href="/static/favicon/wikipedia.ico">\n<link rel="license" href="//creativecommons.org/licenses/by-sa/4.0/">\n<style>\n.sprite{background-image:linear-gradient(transparent,transparent),url(portal/wikipedia.org/assets/img/sprite-de847d1a.svg);background-repeat:no-repeat;display:inline-block;vertical-align:middle}.svg-Commons-logo_sister{background-position:0 0;width:47px;height:47px}.svg-MediaWiki-logo_sister{background-position:0 -47px;width:42px;height:42px}.svg-Meta-Wiki-logo_sister{background-position:0 -89px;width:37px;height:37px}.svg-Wikibooks-logo_sister{background-position:0 -126px;width:37px;height:37px}.svg-Wikidata-logo_sister{background-position:0 -163px;width:49px;height:49px}.svg-Wikifunctions-logo_sister{background-position:0 -212px;width:50px;height:50px}.svg-Wikimedia-logo_black{background-position:0 -262px;width:42px;height:42px}.svg-Wikipedia_wordmark{background-position:0 -304px;width:176px;height:32px}.svg-Wikiquote-logo_sister{background-position:0 -336px;width:42px;height:42px}.svg-Wikisource-logo_sister{background-position:0 -378px;width:39px;height:39px}.svg-Wikispecies-logo_sister{background-position:0 -417px;width:42px;height:42px}.svg-Wikiversity-logo_sister{background-position:0 -459px;width:43px;height:37px}.svg-Wikivoyage-logo_sister{background-position:0 -496px;width:36px;height:36px}.svg-Wiktionary-logo_sister{background-position:0 -532px;width:37px;height:37px}.svg-arrow-down{background-position:0 -569px;width:12px;height:8px}.svg-arrow-down-blue{background-position:0 -577px;width:14px;height:14px}.svg-badge_google_play_store{background-position:0 -591px;width:124px;height:38px}.svg-badge_ios_app_store{background-position:0 -629px;width:110px;height:38px}.svg-language-icon{background-position:0 -667px;width:22px;height:22px}.svg-noimage{background-position:0 -689px;width:58px;height:58px}.svg-search-icon{background-position:0 -747px;width:22px;height:22px}.svg-wikipedia_app_tile{background-position:0 -769px;width:42px;height:42px}\n</style>\n<style>\n:root{--background-image-input-checkbox--checked:url(\'data:image/svg+xml;utf8,<svg xmlns="http://www.w3.org/2000/svg" width="20" height="20" viewBox="0 0 20 20"><path fill="%23fff" d="M7 14.17L2.83 10l-1.41 1.41L7 17 19 5l-1.41-1.42z"/></svg>\');--color-base:#202122;--color-base-fixed:#202122;--color-base--hover:#404244;--color-emphasized:#101418;--color-subtle:#54595d;--color-placeholder:#72777d;--color-disabled:#a2a9b1;--color-disabled-emphasized:#a2a9b1;--color-inverted:#fff;--color-inverted-fixed:#fff;--color-progressive:#36c;--color-progressive--hover:#3056a9;--color-progressive--active:#233566;--color-progressive--focus:#36c;--color-destructive:#bf3c2c;--color-destructive--hover:#9f3526;--color-destructive--active:#612419;--color-destructive--focus:#36c;--color-visited:#6a60b0;--color-visited--hover:#534fa3;--color-visited--active:#353262;--color-destructive--visited:#9f5555;--color-destructive--visited--hover:#854848;--color-destructive--visited--active:#512e2e;--color-error:#bf3c2c;--color-error--hover:#9f3526;--color-error--active:#612419;--color-warning:#886425;--color-success:#177860;--color-notice:#404244;--color-icon-error:#f54739;--color-icon-warning:#ab7f2a;--color-icon-success:#099979;--color-icon-notice:#72777d;--color-content-added:#006400;--color-content-removed:#8b0000;--opacity-base:1;--opacity-medium:0.65;--opacity-low:0.3;--opacity-transparent:0;- ...

# %%
print(response.text.split('</title>')[0].split('<title>')[1])
# Out:
# Wikipedia

# %%
api_key = "2203972e70f562c3bea789d695129ca6"
city = "Bhola"
params = {
    'q': city,
    'appid': api_key,
    'units': 'metric'
}
response = requests.get('https://api.openweathermap.org/data/2.5/weather', params=params)
if response.status_code == 200:
    weather_data = response.json()
    print(f"Temperature in {city}: {weather_data['main']['temp']}°C")
    print(f"Weather: {weather_data['weather'][0]['description']}")
# Out:
# Temperature in Bhola: 26.52°C
# Weather: few clouds

# %%
response.url
# Out:
# 'https://api.openweathermap.org/data/2.5/weather?q=Bhola&appid=2203972e70f562c3bea789d695129ca6&units=metric'

# %%
response = requests.get('https://jsonplaceholder.typicode.com/posts/1')
if response.status_code == 200:
    post = response.json()
    print(f"Post Title: {post['title']}")
    print(f"Post Body: {post['body']}")
# Out:
# Post Title: sunt aut facere repellat provident occaecati excepturi optio reprehenderit
# Post Body: quia et suscipit
# suscipit recusandae consequuntur expedita et cum
# reprehenderit molestiae ut ut quas totam
# nostrum rerum est autem sunt rem eveniet architecto

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get('https://news.ycombinator.com/')
soup = BeautifulSoup(response.text, 'html.parser')
stories = soup.find_all('span', class_='titleline')

print("Top Hacker News stories:")
for i, story in enumerate(stories[:5], 1):
    title = story.find('a').text
    link = story.find('a')['href']
    print(f"{i}. {title}")
    print(f"   Link: {link}")
# Out:
# Top Hacker News stories:
# 1. Block YouTube ads on AppleTV by decrypting and stripping ads from Profobuf
#    Link: https://ericdraken.com/pfsense-decrypt-ad-traffic/
# 2. The Model Is the Product
#    Link: https://vintagedata.org/blog/posts/model-is-the-product
# 3. Extracting DNA from the air – DNA evidence of human occupancy in indoor premises
#    Link: https://www.nature.com/articles/s41598-023-46151-7
# 4. SheepIt Render Farm server code goes open source
#    Link: https://gitlab.com/sheepitrenderfarm
# 5. Sesame CSM: A Conversational Speech Generation Model
#    Link: https://github.com/SesameAILabs/csm

# %% [markdown]
# ### Post Method

# %%
uri = 'https://httpbin.org/post'
data = {
    'username': 'john_doe',
    'password': 's3cr3t'
}

# %%
response = requests.post(uri, data=data)

# %%
response.json()
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'password': 's3cr3t', 'username': 'john_doe'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate, br, zstd',
#   'Content-Length': '33',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.32.3',
#   'X-Amzn-Trace-Id': 'Root=1-67d976a2-0deefc75220235225d61fc11'},
#  'json': None,
#  'origin': '118.179.116.241',
#  'url': 'https://httpbin.org/post'}

# %%
response.json()['headers']['Content-Type'].split('/')[-1]
# Out:
# 'x-www-form-urlencoded'

# %%
response = requests.post(uri, json=data)

# %%
response.json()
# Out:
# {'args': {},
#  'data': '{"username": "john_doe", "password": "s3cr3t"}',
#  'files': {},
#  'form': {},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate, br, zstd',
#   'Content-Length': '46',
#   'Content-Type': 'application/json',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.32.3',
#   'X-Amzn-Trace-Id': 'Root=1-67d976cd-70d558ec1503273a64aad485'},
#  'json': {'password': 's3cr3t', 'username': 'john_doe'},
#  'origin': '118.179.116.241',
#  'url': 'https://httpbin.org/post'}

# %% [markdown]
# ### Sending JSON data to JSONPlaceholder

# %%
import json

# Data to send as JSON
post_data = {
    'title': 'My New Post',
    'body': 'This is the content of my post',
    'userId': 1
}

# Send POST request with JSON data
headers = {'Content-Type': 'application/json'}
response = requests.post(
    'https://jsonplaceholder.typicode.com/posts',
    data=json.dumps(post_data),
    headers=headers
)

# Alternative way to send JSON data
# response = requests.post(
#     'https://jsonplaceholder.typicode.com/posts',
#     json=post_data  # requests automatically handles JSON serialization
# )

print(f"Status code: {response.status_code}")
print(f"Response: {response.json()}")
# Out:
# Status code: 201
# Response: {'title': 'My New Post', 'body': 'This is the content of my post', 'userId': 1, 'id': 101}

# %% [markdown]
# ### Form submission

# %%
# Contact form submission example
form_data = {
    'name': 'John Doe',
    'email': 'john@example.com',
    'message': 'Hello, this is a test message!'
}

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
}

response = requests.post('https://httpbin.org/post', data=form_data, headers=headers)
print(f"Status code: {response.status_code}")
print(response.json())
# Out:
# Status code: 200
# {'args': {}, 'data': '', 'files': {}, 'form': {'email': 'john@example.com', 'message': 'Hello, this is a test message!', 'name': 'John Doe'}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Content-Length': '81', 'Content-Type': 'application/x-www-form-urlencoded', 'Host': 'httpbin.org', 'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36', 'X-Amzn-Trace-Id': 'Root=1-67d97710-6db32edd0b99b4c06f350a1b'}, 'json': None, 'origin': '118.179.116.241', 'url': 'https://httpbin.org/post'}

# %%
response.json()['headers']['Content-Type'].split('/')[-1]
# Out:
# 'x-www-form-urlencoded'

# %% [markdown]
# ### File upload to a server

# %%
# File upload example
files = {
    'file': ('report.csv', open('report.csv', 'rb'), 'text/csv')
}

response = requests.post('https://httpbin.org/post', files=files)
print(f"Status code: {response.status_code}")
print(response.json())
# Out:
# Status code: 200
# {'args': {}, 'data': '', 'files': {'file': 'name,age\nAlice,30\nBob,25\nCharlie,40'}, 'form': {}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Content-Length': '205', 'Content-Type': 'multipart/form-data; boundary=f37c2a30bd8f9de01c941f1b51609098', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.32.3', 'X-Amzn-Trace-Id': 'Root=1-67d97721-6d8f714254d555e62262f885'}, 'json': None, 'origin': '118.179.116.241', 'url': 'https://httpbin.org/post'}

# %%
response.json()['files']['file']
# Out:
# 'name,age\nAlice,30\nBob,25\nCharlie,40'

# %% [markdown]
# ### Put Method

# %%
uri = 'https://httpbin.org/put'
data = {
    'username': 'john_doe',
    'password': 's3cr3t'
}

# %%
response = requests.put(uri, data=data)

# %%
response.json()
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'password': 's3cr3t', 'username': 'john_doe'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate, br, zstd',
#   'Content-Length': '33',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.32.3',
#   'X-Amzn-Trace-Id': 'Root=1-67d9772e-4f2e4ad93c7c7e224f3e42ed'},
#  'json': None,
#  'origin': '118.179.116.241',
#  'url': 'https://httpbin.org/put'}

# %% [markdown]
# ### Delete Method

# %%
uri = 'https://httpbin.org/delete'

# %%
response = requests.delete(uri)

# %%
response.json()
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate, br, zstd',
#   'Content-Length': '0',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.32.3',
#   'X-Amzn-Trace-Id': 'Root=1-67d97737-7a3b65e7612c5fd7601f393d'},
#  'json': None,
#  'origin': '118.179.116.241',
#  'url': 'https://httpbin.org/delete'}

# %% [markdown]
# ### Headers

# %%
uri = 'https://httpbin.org/headers'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept': 'application/json',
    'Content-Type': 'application/json',
    'X-Custom-Header': 'value',
    'Authorization': 'YourTokenHere'
}

# %%
response = requests.get(uri, headers=headers)

# %%
response.json()
# Out:
# {'headers': {'Accept': 'application/json',
#   'Accept-Encoding': 'gzip, deflate, br, zstd',
#   'Accept-Language': 'en-US,en;q=0.5',
#   'Authorization': 'YourTokenHere',
#   'Content-Type': 'application/json',
#   'Host': 'httpbin.org',
#   'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36',
#   'X-Amzn-Trace-Id': 'Root=1-67d97747-49484c1e3f4d0cdc1ce1c229',
#   'X-Custom-Header': 'value'}}

# %%
response.headers
# Out:
# {'Date': 'Tue, 18 Mar 2025 13:38:19 GMT', 'Content-Type': 'application/json', 'Content-Length': '441', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}

# %%
type(response.headers)
# Out:
# requests.structures.CaseInsensitiveDict

# %%
dict(response.headers)
# Out:
# {'Date': 'Mon, 17 Mar 2025 16:35:41 GMT',
#  'Content-Type': 'application/json',
#  'Content-Length': '441',
#  'Connection': 'keep-alive',
#  'Server': 'gunicorn/19.9.0',
#  'Access-Control-Allow-Origin': '*',
#  'Access-Control-Allow-Credentials': 'true'}

# %%
response.json()['headers']
# Out:
# {'Accept': 'application/json',
#  'Accept-Encoding': 'gzip, deflate, br, zstd',
#  'Accept-Language': 'en-US,en;q=0.5',
#  'Authorization': 'YourTokenHere',
#  'Content-Type': 'application/json',
#  'Host': 'httpbin.org',
#  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36',
#  'X-Amzn-Trace-Id': 'Root=1-67d84f5a-0e587ef549f6d0372680f312',
#  'X-Custom-Header': 'value'}

# %%
for key, value in response.json()['headers'].items():
    print(f"{key:<16}: {value}")
# Out:
# Accept          : application/json
# Accept-Encoding : gzip, deflate, br, zstd
# Accept-Language : en-US,en;q=0.5
# Authorization   : YourTokenHere
# Content-Type    : application/json
# Host            : httpbin.org
# User-Agent      : Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36
# X-Amzn-Trace-Id : Root=1-67d84f5a-0e587ef549f6d0372680f312
# X-Custom-Header : value

# %% [markdown]
# ### Response Object

# %%
uri = 'https://api.github.com'

# %%
response = requests.get(uri)

# %%
response.status_code
# Out:
# 200

# %%
response.headers
# Out:
# {'Date': 'Mon, 17 Mar 2025 17:47:33 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept,Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"4f825cc84e1c733059d46e76e6df9db557ae5254f9625dfe8e1b09499c449438"', 'X-GitHub-Media-Type': 'github.v3; format=json', 'x-github-api-version-selected': '2022-11-28', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'Server': 'github.com', 'Accept-Ranges': 'bytes', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '58', 'X-RateLimit-Reset': '1742236321', 'X-RateLimit-Resource': 'core', 'X-RateLimit-Used': '2', 'Content-Length': '510', 'X-GitHub-Request-Id': 'C172:0A7E:4A276F:5955A3:67D86035'}

# %%
response.content[:1000]
# Out:
# b'{"current_user_url":"https://api.github.com/user","current_user_authorizations_html_url":"https://github.com/settings/connections/applications{/client_id}","authorizations_url":"https://api.github.com/authorizations","code_search_url":"https://api.github.com/search/code?q={query}{&page,per_page,sort,order}","commit_search_url":"https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}","emails_url":"https://api.github.com/user/emails","emojis_url":"https://api.github.com/emojis","events_url":"https://api.github.com/events","feeds_url":"https://api.github.com/feeds","followers_url":"https://api.github.com/user/followers","following_url":"https://api.github.com/user/following{/target}","gists_url":"https://api.github.com/gists{/gist_id}","hub_url":"https://api.github.com/hub","issue_search_url":"https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}","issues_url":"https://api.github.com/issues","keys_url":"https://api.github.com/user/keys","label_searc'

# %%
response.text
# Out:
# '{"current_user_url":"https://api.github.com/user","current_user_authorizations_html_url":"https://github.com/settings/connections/applications{/client_id}","authorizations_url":"https://api.github.com/authorizations","code_search_url":"https://api.github.com/search/code?q={query}{&page,per_page,sort,order}","commit_search_url":"https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}","emails_url":"https://api.github.com/user/emails","emojis_url":"https://api.github.com/emojis","events_url":"https://api.github.com/events","feeds_url":"https://api.github.com/feeds","followers_url":"https://api.github.com/user/followers","following_url":"https://api.github.com/user/following{/target}","gists_url":"https://api.github.com/gists{/gist_id}","hub_url":"https://api.github.com/hub","issue_search_url":"https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}","issues_url":"https://api.github.com/issues","keys_url":"https://api.github.com/user/keys","label_search_url":"https://api.github.com/search/labels?q={query}&repository_id={repository_id}{&page,per_page}","notifications_url":"https://api.github.com/notifications","organization_url":"https://api.github.com/orgs/{org}","organization_repositories_url":"https://api.github.com/orgs/{org}/repos{?type,page,per_page,sort}","organization_teams_url":"https://api.github.com/orgs/{org}/teams","public_gists_url":"https://api.github.com/gists/public","rate_limit_url":"https://api.github.com/rate_limit","repository_url":"https://api.github.com/repos/{owner}/{repo}","repository_search_url":"https://api.github.com/search/repositories?q={query}{&page,per_page,sort,order}","current_user_repositories_url":"https://api.github.com/user/repos{?type,page,per_page,sort}","starred_url":"https://api.github.com/user/starred{/owner}{/repo}","starred_gists_url":"https://api.github.com/gists/starred","topic_search_url":"https://api.github.com/search/topics?q={query}{&page,per_page}","user_url":"https://api.github.com/users/{user}","user_organizations_url":"https://api.github.com/user/orgs","user_repositories_url":"https://api.github.com/users/{user}/repos{?type,page,per_page,sort}","user_search_url":"https://api.github.com/search/users?q={query}{&page,per_page,sort,order}"}'

# %%
type(response.text)
# Out:
# str

# %%
response.content
# Out:
# b'{"current_user_url":"https://api.github.com/user","current_user_authorizations_html_url":"https://github.com/settings/connections/applications{/client_id}","authorizations_url":"https://api.github.com/authorizations","code_search_url":"https://api.github.com/search/code?q={query}{&page,per_page,sort,order}","commit_search_url":"https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}","emails_url":"https://api.github.com/user/emails","emojis_url":"https://api.github.com/emojis","events_url":"https://api.github.com/events","feeds_url":"https://api.github.com/feeds","followers_url":"https://api.github.com/user/followers","following_url":"https://api.github.com/user/following{/target}","gists_url":"https://api.github.com/gists{/gist_id}","hub_url":"https://api.github.com/hub","issue_search_url":"https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}","issues_url":"https://api.github.com/issues","keys_url":"https://api.github.com/user/keys","label_search_url":"https://api.github.com/search/labels?q={query}&repository_id={repository_id}{&page,per_page}","notifications_url":"https://api.github.com/notifications","organization_url":"https://api.github.com/orgs/{org}","organization_repositories_url":"https://api.github.com/orgs/{org}/repos{?type,page,per_page,sort}","organization_teams_url":"https://api.github.com/orgs/{org}/teams","public_gists_url":"https://api.github.com/gists/public","rate_limit_url":"https://api.github.com/rate_limit","repository_url":"https://api.github.com/repos/{owner}/{repo}","repository_search_url":"https://api.github.com/search/repositories?q={query}{&page,per_page,sort,order}","current_user_repositories_url":"https://api.github.com/user/repos{?type,page,per_page,sort}","starred_url":"https://api.github.com/user/starred{/owner}{/repo}","starred_gists_url":"https://api.github.com/gists/starred","topic_search_url":"https://api.github.com/search/topics?q={query}{&page,per_page}","user_url":"https://api.github.com/users/{user}","user_organizations_url":"https://api.github.com/user/orgs","user_repositories_url":"https://api.github.com/users/{user}/repos{?type,page,per_page,sort}","user_search_url":"https://api.github.com/search/users?q={query}{&page,per_page,sort,order}"}'

# %%
type(response.content)
# Out:
# bytes

# %%
dict(response.headers)
# Out:
# {'Date': 'Mon, 17 Mar 2025 17:47:33 GMT',
#  'Content-Type': 'application/json; charset=utf-8',
#  'Cache-Control': 'public, max-age=60, s-maxage=60',
#  'Vary': 'Accept,Accept-Encoding, Accept, X-Requested-With',
#  'ETag': 'W/"4f825cc84e1c733059d46e76e6df9db557ae5254f9625dfe8e1b09499c449438"',
#  'X-GitHub-Media-Type': 'github.v3; format=json',
#  'x-github-api-version-selected': '2022-11-28',
#  'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset',
#  'Access-Control-Allow-Origin': '*',
#  'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload',
#  'X-Frame-Options': 'deny',
#  'X-Content-Type-Options': 'nosniff',
#  'X-XSS-Protection': '0',
#  'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin',
#  'Content-Security-Policy': "default-src 'none'",
#  'Content-Encoding': 'gzip',
#  'Server': 'github.com',
#  'Accept-Ranges': 'bytes',
#  'X-RateLimit-Limit': '60',
#  'X-RateLimit-Remaining': '58',
#  'X-RateLimit-Reset': '1742236321',
#  'X-RateLimit-Resource': 'core',
#  'X-RateLimit-Used': '2',
#  'Content-Length': '510',
#  'X-GitHub-Request-Id': 'C172:0A7E:4A276F:5955A3:67D86035'}

# %%
for key, value in dict(response.json()).items():
    print(f"{key:<30}: {value}")
# Out:
# current_user_url              : https://api.github.com/user
# current_user_authorizations_html_url: https://github.com/settings/connections/applications{/client_id}
# authorizations_url            : https://api.github.com/authorizations
# code_search_url               : https://api.github.com/search/code?q={query}{&page,per_page,sort,order}
# commit_search_url             : https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}
# emails_url                    : https://api.github.com/user/emails
# emojis_url                    : https://api.github.com/emojis
# events_url                    : https://api.github.com/events
# feeds_url                     : https://api.github.com/feeds
# followers_url                 : https://api.github.com/user/followers
# following_url                 : https://api.github.com/user/following{/target}
# gists_url                     : https://api.github.com/gists{/gist_id}
# hub_url                       : https://api.github.com/hub
# issue_search_url              : https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}
# issues_url                    : https://api.github.com/issues
# keys_url                      : https://api.github.com/user/keys
# label_search_url              : https://api.github.com/search/labels?q={query}&repository_id={repository_id}{&page,per_page}
# notifications_url             : https://api.github.com/notifications
# organization_url              : https://api.github.com/orgs/{org}
# organization_repositories_url : https://api.github.com/orgs/{org}/repos{?type,page,per_page,sort}
# organization_teams_url        : https://api.github.com/orgs/{org}/teams
# public_gists_url              : https://api.github.com/gists/public
# rate_limit_url                : https://api.github.com/rate_limit
# repository_url                : https://api.github.com/repos/{owner}/{repo}
# repository_search_url         : https://api.github.com/search/repositories?q={query}{&page,per_page,sort,order}
# current_user_repositories_url : https://api.github.com/user/repos{?type,page,per_page,sort}
# starred_url                   : https://api.github.com/user/starred{/owner}{/repo}
# starred_gists_url             : https://api.github.com/gists/starred
# topic_search_url              : https://api.github.com/search/topics?q={query}{&page,per_page}
# user_url                      : https://api.github.com/users/{user}
# user_organizations_url        : https://api.github.com/user/orgs
# user_repositories_url         : https://api.github.com/users/{user}/repos{?type,page,per_page,sort}
# user_search_url               : https://api.github.com/search/users?q={query}{&page,per_page,sort,order}
